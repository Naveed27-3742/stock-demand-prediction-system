# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
# Out:
# c:\Users\Win 10\Desktop\Math for ML Engineering projects\stock_prediction

# %%
import pandas as pd
from src.data_loader import load_data
from src.config import DATA_PATH

# %%
df = load_data(DATA_PATH)

# %%
df.sample(5)
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 59127  2023-08-15     S002      P0008  Groceries  South              130
# 22295  2022-08-11     S005      P0016       Toys  North              380
# 50809  2023-05-24     S001      P0010  Furniture  North              288
# 19427  2022-07-14     S002      P0008  Groceries  South               89
# 73045  2024-01-01     S003      P0006       Toys   East              100
#
#        Units Sold  Units Ordered   Price  Discount Weather Condition  \
# 59127         102            158   29.79         0             Sunny
# 22295         153            329   37.29        10            Cloudy
# 50809         111              0  130.35        10             Sunny
# 19427          59             86   23.41        10            Cloudy
# 73045          59             62   32.42        10            Cloudy
#
#        Promotion  Competitor Pricing Seasonality  Epidemic  Demand
# 59127          0               33.65      Summer         0     145
# 22295          0               36.93      Summer         0     132
# 50809          0              115.75      Spring         0      95
# 19427          0               22.66      Summer         1      85
# 73045          0               30.36      Winter         1      57

# %%
df.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand'],
#       dtype='object')

# %%
df.shape
# Out:
# (76000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76000 entries, 0 to 75999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                76000 non-null  object
#  1   Store ID            76000 non-null  object
#  2   Product ID          76000 non-null  object
#  3   Category            76000 non-null  object
#  4   Region              76000 non-null  object
#  5   Inventory Level     76000 non-null  int64
#  6   Units Sold          76000 non-null  int64
#  7   Units Ordered       76000 non-null  int64
#  8   Price               76000 non-null  float64
#  9   Discount            76000 non-null  int64
#  10  Weather Condition   76000 non-null  object
#  11  Promotion           76000 non-null  int64
#  12  Competitor Pricing  76000 non-null  float64
#  13  Seasonality         76000 non-null  object
#  14  Epidemic            76000 non-null  int64
#  15  Demand              76000 non-null  int64
# dtypes: float64(2), int64(7), object(7)
# memory usage: 9.3+ MB

# %%
df.describe()
# Out:
#        Inventory Level    Units Sold  Units Ordered         Price  \
# count     76000.000000  76000.000000   76000.000000  76000.000000
# mean        301.062842     88.827316      89.090645     67.726028
# std         226.510161     43.994525     162.404627     39.377899
# min           0.000000      0.000000       0.000000      4.740000
# 25%         136.000000     58.000000       0.000000     31.997500
# 50%         227.000000     84.000000       0.000000     64.500000
# 75%         408.000000    114.000000     121.000000     95.830000
# max        2267.000000    426.000000    1616.000000    228.030000
#
#            Discount     Promotion  Competitor Pricing      Epidemic  \
# count  76000.000000  76000.000000        76000.000000  76000.000000
# mean       9.087039      0.328947           69.454029      0.200000
# std        7.475781      0.469834           40.943818      0.400003
# min        0.000000      0.000000            4.290000      0.000000
# 25%        5.000000      0.000000           32.620000      0.000000
# 50%       10.000000      0.000000           65.700000      0.000000
# 75%       10.000000      1.000000           97.932500      0.000000
# max       25.000000      1.000000          261.220000      1.000000
#
#              Demand
# count  76000.000000
# mean     104.317158
# std       46.964801
# min        4.000000
# 25%       71.000000
# 50%      100.000000
# 75%      133.000000
# max      430.000000

# %%
df.nunique()
# Out:
# Date                    760
# Store ID                  5
# Product ID               20
# Category                  5
# Region                    4
# Inventory Level        1426
# Units Sold              330
# Units Ordered           996
# Price                 15396
# Discount                  6
# Weather Condition         4
# Promotion                 2
# Competitor Pricing    15963
# Seasonality               4
# Epidemic                  2
# Demand                  340
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                  0
# Store ID              0
# Product ID            0
# Category              0
# Region                0
# Inventory Level       0
# Units Sold            0
# Units Ordered         0
# Price                 0
# Discount              0
# Weather Condition     0
# Promotion             0
# Competitor Pricing    0
# Seasonality           0
# Epidemic              0
# Demand                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
